# %%
def overlap(a, b, min_length=3):
    """ Return length of longest suffix of 'a' matching
        a prefix of 'b' that is at least 'min_length'
        characters long.  If no such overlap exists,
        return 0. """
    start = 0  # start all the way at the left
    while True:
        start = a.find(b[:min_length], start)  # look for b's suffx in a
        if start == -1:  # no more occurrences to right
            return 0
        # found occurrence; check for full suffix/prefix match
        if b.startswith(a[start:]):
            return len(a)-start
        start += 1  # move just past previous match

import itertools

def scs(ss):
    """ Returns shortest common superstring of given
        strings, which must be the same length """
    shortest_sup = None
    count = 0
    for ssperm in itertools.permutations(ss):
        sup = ssperm[0]  # superstring starts as first string
        for i in range(len(ss)-1):
            # overlap adjacent strings A and B in the permutation
            olen = overlap(ssperm[i], ssperm[i+1], min_length=1)
            # add non-overlapping portion of B to superstring
            sup += ssperm[i+1][olen:]
        print("loop: ", i, "sup: ", sup, "length: ", len(sup))
        if len(sup) == 11:
            count += 1
            print("count: ",count)
        if shortest_sup is None or len(sup) < len(shortest_sup):
            shortest_sup = sup  # found shorter superstring
    return shortest_sup  # return shortest

# %%
scs(['CCT', 'CTT','TGC', 'TGG', 'GAT', 'ATT'])
# Out:
# loop:  4 sup:  CCTTGCTGGATT length:  12
# loop:  4 sup:  CCTTGCTGGATTGAT length:  15
# loop:  4 sup:  CCTTGCGATGGATT length:  14
# loop:  4 sup:  CCTTGCGATTGG length:  12
# loop:  4 sup:  CCTTGCATTGGAT length:  13
# loop:  4 sup:  CCTTGCATTGATGG length:  14
# loop:  4 sup:  CCTTGGTGCGATT length:  13
# loop:  4 sup:  CCTTGGTGCATTGAT length:  15
# loop:  4 sup:  CCTTGGATGCATT length:  13
# loop:  4 sup:  CCTTGGATTGC length:  11
# count:  1
# loop:  4 sup:  CCTTGGATTGCGAT length:  14
# loop:  4 sup:  CCTTGGATTGATGC length:  14
# loop:  4 sup:  CCTTGATGCTGGATT length:  15
# loop:  4 sup:  CCTTGATGCATTGG length:  14
# loop:  4 sup:  CCTTGATGGTGCATT length:  15
# loop:  4 sup:  CCTTGATGGATTGC length:  14
# loop:  4 sup:  CCTTGATTGCTGG length:  13
# loop:  4 sup:  CCTTGATTGGTGC length:  13
# loop:  4 sup:  CCTTATTGCTGGAT length:  14
# loop:  4 sup:  CCTTATTGCGATGG length:  14
# loop:  4 sup:  CCTTATTGGTGCGAT length:  15
# loop:  4 sup:  CCTTATTGGATGC length:  13
# loop:  4 sup:  CCTTATTGATGCTGG length:  15
# loop:  4 sup:  CCTTATTGATGGTGC length:  15
# loop:  4 sup:  CCTGCTTGGATT length:  12
# loop:  4 sup:  CCTGCTTGGATTGAT length:  15
# loop:  4 sup:  CCTGCTTGATGGATT length:  15
# loop:  4 sup:  CCTGCTTGATTGG length:  13
# loop:  4 sup:  CCTGCTTATTGGAT length:  14
# loop:  4 sup:  CCTGCTTATTGATGG length:  15
# loop:  4 sup:  CCTGCTGGCTTGATT length:  15
# loop:  4 sup:  CCTGCTGGCTTATTGAT length:  17
# loop:  4 sup:  CCTGCTGGATCTTATT length:  16
# loop:  4 sup:  CCTGCTGGATTCTT length:  14
# loop:  4 sup:  CCTGCTGGATTCTTGAT length:  17
# loop:  4 sup:  CCTGCTGGATTGATCTT length:  17
# loop:  4 sup:  CCTGCGATCTTGGATT length:  16
# loop:  4 sup:  CCTGCGATCTTATTGG length:  16
# loop:  4 sup:  CCTGCGATGGCTTATT length:  16
# loop:  4 sup:  CCTGCGATGGATTCTT length:  16
# loop:  4 sup:  CCTGCGATTCTTGG length:  14
# loop:  4 sup:  CCTGCGATTGGCTT length:  14
# loop:  4 sup:  CCTGCATTCTTGGAT length:  15
# loop:  4 sup:  CCTGCATTCTTGATGG length:  16
# loop:  4 sup:  CCTGCATTGGCTTGAT length:  16
# loop:  4 sup:  CCTGCATTGGATCTT length:  15
# loop:  4 sup:  CCTGCATTGATCTTGG length:  16
# loop:  4 sup:  CCTGCATTGATGGCTT length:  16
# loop:  4 sup:  CCTGGCTTGCGATT length:  14
# loop:  4 sup:  CCTGGCTTGCATTGAT length:  16
# loop:  4 sup:  CCTGGCTTGATGCATT length:  16
# loop:  4 sup:  CCTGGCTTGATTGC length:  14
# loop:  4 sup:  CCTGGCTTATTGCGAT length:  16
# loop:  4 sup:  CCTGGCTTATTGATGC length:  16
# loop:  4 sup:  CCTGGTGCTTGATT length:  14
# loop:  4 sup:  CCTGGTGCTTATTGAT length:  16
# loop:  4 sup:  CCTGGTGCGATCTTATT length:  17
# loop:  4 sup:  CCTGGTGCGATTCTT length:  15
# loop:  4 sup:  CCTGGTGCATTCTTGAT length:  17
# loop:  4 sup:  CCTGGTGCATTGATCTT length:  17
# loop:  4 sup:  CCTGGATCTTGCATT length:  15
# loop:  4 sup:  CCTGGATCTTATTGC length:  15
# loop:  4 sup:  CCTGGATGCTTATT length:  14
# loop:  4 sup:  CCTGGATGCATTCTT length:  15
# loop:  4 sup:  CCTGGATTCTTGC length:  13
# loop:  4 sup:  CCTGGATTGCTT length:  12
# loop:  4 sup:  CCTGGATTCTTGCGAT length:  16
# loop:  4 sup:  CCTGGATTCTTGATGC length:  16
# loop:  4 sup:  CCTGGATTGCTTGAT length:  15
# loop:  4 sup:  CCTGGATTGCGATCTT length:  16
# loop:  4 sup:  CCTGGATTGATCTTGC length:  16
# loop:  4 sup:  CCTGGATTGATGCTT length:  15
# loop:  4 sup:  CCTGATCTTGCTGGATT length:  17
# loop:  4 sup:  CCTGATCTTGCATTGG length:  16
# loop:  4 sup:  CCTGATCTTGGTGCATT length:  17
# loop:  4 sup:  CCTGATCTTGGATTGC length:  16
# loop:  4 sup:  CCTGATCTTATTGCTGG length:  17
# loop:  4 sup:  CCTGATCTTATTGGTGC length:  17
# loop:  4 sup:  CCTGATGCTTGGATT length:  15
# loop:  4 sup:  CCTGATGCTTATTGG length:  15
# loop:  4 sup:  CCTGATGCTGGCTTATT length:  17
# loop:  4 sup:  CCTGATGCTGGATTCTT length:  17
# loop:  4 sup:  CCTGATGCATTCTTGG length:  16
# loop:  4 sup:  CCTGATGCATTGGCTT length:  16
# loop:  4 sup:  CCTGATGGCTTGCATT length:  16
# loop:  4 sup:  CCTGATGGCTTATTGC length:  16
# loop:  4 sup:  CCTGATGGTGCTTATT length:  16
# loop:  4 sup:  CCTGATGGTGCATTCTT length:  17
# loop:  4 sup:  CCTGATGGATTCTTGC length:  16
# loop:  4 sup:  CCTGATGGATTGCTT length:  15
# loop:  4 sup:  CCTGATTCTTGCTGG length:  15
# loop:  4 sup:  CCTGATTCTTGGTGC length:  15
# loop:  4 sup:  CCTGATTGCTTGG length:  13
# loop:  4 sup:  CCTGATTGCTGGCTT length:  15
# loop:  4 sup:  CCTGATTGGCTTGC length:  14
# loop:  4 sup:  CCTGATTGGTGCTT length:  14
# loop:  4 sup:  CCTATTCTTGCTGGAT length:  16
# loop:  4 sup:  CCTATTCTTGCGATGG length:  16
# loop:  4 sup:  CCTATTCTTGGTGCGAT length:  17
# loop:  4 sup:  CCTATTCTTGGATGC length:  15
# loop:  4 sup:  CCTATTCTTGATGCTGG length:  17
# loop:  4 sup:  CCTATTCTTGATGGTGC length:  17
# loop:  4 sup:  CCTATTGCTTGGAT length:  14
# loop:  4 sup:  CCTATTGCTTGATGG length:  15
# loop:  4 sup:  CCTATTGCTGGCTTGAT length:  17
# loop:  4 sup:  CCTATTGCTGGATCTT length:  16
# loop:  4 sup:  CCTATTGCGATCTTGG length:  16
# loop:  4 sup:  CCTATTGCGATGGCTT length:  16
# loop:  4 sup:  CCTATTGGCTTGCGAT length:  16
# loop:  4 sup:  CCTATTGGCTTGATGC length:  16
# loop:  4 sup:  CCTATTGGTGCTTGAT length:  16
# loop:  4 sup:  CCTATTGGTGCGATCTT length:  17
# loop:  4 sup:  CCTATTGGATCTTGC length:  15
# loop:  4 sup:  CCTATTGGATGCTT length:  14
# loop:  4 sup:  CCTATTGATCTTGCTGG length:  17
# loop:  4 sup:  CCTATTGATCTTGGTGC length:  17
# loop:  4 sup:  CCTATTGATGCTTGG length:  15
# loop:  4 sup:  CCTATTGATGCTGGCTT length:  17
# loop:  4 sup:  CCTATTGATGGCTTGC length:  16
# loop:  4 sup:  CCTATTGATGGTGCTT length:  16
# loop:  4 sup:  CTTCCTGCTGGATT length:  14
# loop:  4 sup:  CTTCCTGCTGGATTGAT length:  17
# loop:  4 sup:  CTTCCTGCGATGGATT length:  16
# loop:  4 sup:  CTTCCTGCGATTGG length:  14
# loop:  4 sup:  CTTCCTGCATTGGAT length:  15
# loop:  4 sup:  CTTCCTGCATTGATGG length:  16
# loop:  4 sup:  CTTCCTGGTGCGATT length:  15
# loop:  4 sup:  CTTCCTGGTGCATTGAT length:  17
# loop:  4 sup:  CTTCCTGGATGCATT length:  15
# loop:  4 sup:  CTTCCTGGATTGC length:  13
# loop:  4 sup:  CTTCCTGGATTGCGAT length:  16
# loop:  4 sup:  CTTCCTGGATTGATGC length:  16
# loop:  4 sup:  CTTCCTGATGCTGGATT length:  17
# loop:  4 sup:  CTTCCTGATGCATTGG length:  16
# loop:  4 sup:  CTTCCTGATGGTGCATT length:  17
# loop:  4 sup:  CTTCCTGATGGATTGC length:  16
# loop:  4 sup:  CTTCCTGATTGCTGG length:  15
# loop:  4 sup:  CTTCCTGATTGGTGC length:  15
# loop:  4 sup:  CTTCCTATTGCTGGAT length:  16
# loop:  4 sup:  CTTCCTATTGCGATGG length:  16
# loop:  4 sup:  CTTCCTATTGGTGCGAT length:  17
# loop:  4 sup:  CTTCCTATTGGATGC length:  15
# loop:  4 sup:  CTTCCTATTGATGCTGG length:  17
# loop:  4 sup:  CTTCCTATTGATGGTGC length:  17
# loop:  4 sup:  CTTGCCTGGATT length:  12
# loop:  4 sup:  CTTGCCTGGATTGAT length:  15
# loop:  4 sup:  CTTGCCTGATGGATT length:  15
# loop:  4 sup:  CTTGCCTGATTGG length:  13
# loop:  4 sup:  CTTGCCTATTGGAT length:  14
# loop:  4 sup:  CTTGCCTATTGATGG length:  15
# loop:  4 sup:  CTTGCTGGCCTGATT length:  15
# loop:  4 sup:  CTTGCTGGCCTATTGAT length:  17
# loop:  4 sup:  CTTGCTGGATCCTATT length:  16
# loop:  4 sup:  CTTGCTGGATTCCT length:  14
# loop:  4 sup:  CTTGCTGGATTCCTGAT length:  17
# loop:  4 sup:  CTTGCTGGATTGATCCT length:  17
# loop:  4 sup:  CTTGCGATCCTGGATT length:  16
# loop:  4 sup:  CTTGCGATCCTATTGG length:  16
# loop:  4 sup:  CTTGCGATGGCCTATT length:  16
# loop:  4 sup:  CTTGCGATGGATTCCT length:  16
# loop:  4 sup:  CTTGCGATTCCTGG length:  14
# loop:  4 sup:  CTTGCGATTGGCCT length:  14
# loop:  4 sup:  CTTGCATTCCTGGAT length:  15
# loop:  4 sup:  CTTGCATTCCTGATGG length:  16
# loop:  4 sup:  CTTGCATTGGCCTGAT length:  16
# loop:  4 sup:  CTTGCATTGGATCCT length:  15
# loop:  4 sup:  CTTGCATTGATCCTGG length:  16
# loop:  4 sup:  CTTGCATTGATGGCCT length:  16
# loop:  4 sup:  CTTGGCCTGCGATT length:  14
# loop:  4 sup:  CTTGGCCTGCATTGAT length:  16
# loop:  4 sup:  CTTGGCCTGATGCATT length:  16
# loop:  4 sup:  CTTGGCCTGATTGC length:  14
# loop:  4 sup:  CTTGGCCTATTGCGAT length:  16
# loop:  4 sup:  CTTGGCCTATTGATGC length:  16
# loop:  4 sup:  CTTGGTGCCTGATT length:  14
# loop:  4 sup:  CTTGGTGCCTATTGAT length:  16
# loop:  4 sup:  CTTGGTGCGATCCTATT length:  17
# loop:  4 sup:  CTTGGTGCGATTCCT length:  15
# loop:  4 sup:  CTTGGTGCATTCCTGAT length:  17
# loop:  4 sup:  CTTGGTGCATTGATCCT length:  17
# loop:  4 sup:  CTTGGATCCTGCATT length:  15
# loop:  4 sup:  CTTGGATCCTATTGC length:  15
# loop:  4 sup:  CTTGGATGCCTATT length:  14
# loop:  4 sup:  CTTGGATGCATTCCT length:  15
# loop:  4 sup:  CTTGGATTCCTGC length:  13
# loop:  4 sup:  CTTGGATTGCCT length:  12
# loop:  4 sup:  CTTGGATTCCTGCGAT length:  16
# loop:  4 sup:  CTTGGATTCCTGATGC length:  16
# loop:  4 sup:  CTTGGATTGCCTGAT length:  15
# loop:  4 sup:  CTTGGATTGCGATCCT length:  16
# loop:  4 sup:  CTTGGATTGATCCTGC length:  16
# loop:  4 sup:  CTTGGATTGATGCCT length:  15
# loop:  4 sup:  CTTGATCCTGCTGGATT length:  17
# loop:  4 sup:  CTTGATCCTGCATTGG length:  16
# loop:  4 sup:  CTTGATCCTGGTGCATT length:  17
# loop:  4 sup:  CTTGATCCTGGATTGC length:  16
# loop:  4 sup:  CTTGATCCTATTGCTGG length:  17
# loop:  4 sup:  CTTGATCCTATTGGTGC length:  17
# loop:  4 sup:  CTTGATGCCTGGATT length:  15
# loop:  4 sup:  CTTGATGCCTATTGG length:  15
# loop:  4 sup:  CTTGATGCTGGCCTATT length:  17
# loop:  4 sup:  CTTGATGCTGGATTCCT length:  17
# loop:  4 sup:  CTTGATGCATTCCTGG length:  16
# loop:  4 sup:  CTTGATGCATTGGCCT length:  16
# loop:  4 sup:  CTTGATGGCCTGCATT length:  16
# loop:  4 sup:  CTTGATGGCCTATTGC length:  16
# loop:  4 sup:  CTTGATGGTGCCTATT length:  16
# loop:  4 sup:  CTTGATGGTGCATTCCT length:  17
# loop:  4 sup:  CTTGATGGATTCCTGC length:  16
# loop:  4 sup:  CTTGATGGATTGCCT length:  15
# loop:  4 sup:  CTTGATTCCTGCTGG length:  15
# loop:  4 sup:  CTTGATTCCTGGTGC length:  15
# loop:  4 sup:  CTTGATTGCCTGG length:  13
# loop:  4 sup:  CTTGATTGCTGGCCT length:  15
# loop:  4 sup:  CTTGATTGGCCTGC length:  14
# loop:  4 sup:  CTTGATTGGTGCCT length:  14
# loop:  4 sup:  CTTATTCCTGCTGGAT length:  16
# loop:  4 sup:  CTTATTCCTGCGATGG length:  16
# loop:  4 sup:  CTTATTCCTGGTGCGAT length:  17
# loop:  4 sup:  CTTATTCCTGGATGC length:  15
# loop:  4 sup:  CTTATTCCTGATGCTGG length:  17
# loop:  4 sup:  CTTATTCCTGATGGTGC length:  17
# loop:  4 sup:  CTTATTGCCTGGAT length:  14
# loop:  4 sup:  CTTATTGCCTGATGG length:  15
# loop:  4 sup:  CTTATTGCTGGCCTGAT length:  17
# loop:  4 sup:  CTTATTGCTGGATCCT length:  16
# loop:  4 sup:  CTTATTGCGATCCTGG length:  16
# loop:  4 sup:  CTTATTGCGATGGCCT length:  16
# loop:  4 sup:  CTTATTGGCCTGCGAT length:  16
# loop:  4 sup:  CTTATTGGCCTGATGC length:  16
# loop:  4 sup:  CTTATTGGTGCCTGAT length:  16
# loop:  4 sup:  CTTATTGGTGCGATCCT length:  17
# loop:  4 sup:  CTTATTGGATCCTGC length:  15
# loop:  4 sup:  CTTATTGGATGCCT length:  14
# loop:  4 sup:  CTTATTGATCCTGCTGG length:  17
# loop:  4 sup:  CTTATTGATCCTGGTGC length:  17
# loop:  4 sup:  CTTATTGATGCCTGG length:  15
# loop:  4 sup:  CTTATTGATGCTGGCCT length:  17
# loop:  4 sup:  CTTATTGATGGCCTGC length:  16
# loop:  4 sup:  CTTATTGATGGTGCCT length:  16
# loop:  4 sup:  TGCCTTGGATT length:  11
# count:  2
# loop:  4 sup:  TGCCTTGGATTGAT length:  14
# loop:  4 sup:  TGCCTTGATGGATT length:  14
# loop:  4 sup:  TGCCTTGATTGG length:  12
# loop:  4 sup:  TGCCTTATTGGAT length:  13
# loop:  4 sup:  TGCCTTATTGATGG length:  14
# loop:  4 sup:  TGCCTGGCTTGATT length:  14
# loop:  4 sup:  TGCCTGGCTTATTGAT length:  16
# loop:  4 sup:  TGCCTGGATCTTATT length:  15
# loop:  4 sup:  TGCCTGGATTCTT length:  13
# loop:  4 sup:  TGCCTGGATTCTTGAT length:  16
# loop:  4 sup:  TGCCTGGATTGATCTT length:  16
# loop:  4 sup:  TGCCTGATCTTGGATT length:  16
# loop:  4 sup:  TGCCTGATCTTATTGG length:  16
# loop:  4 sup:  TGCCTGATGGCTTATT length:  16
# loop:  4 sup:  TGCCTGATGGATTCTT length:  16
# loop:  4 sup:  TGCCTGATTCTTGG length:  14
# loop:  4 sup:  TGCCTGATTGGCTT length:  14
# loop:  4 sup:  TGCCTATTCTTGGAT length:  15
# loop:  4 sup:  TGCCTATTCTTGATGG length:  16
# loop:  4 sup:  TGCCTATTGGCTTGAT length:  16
# loop:  4 sup:  TGCCTATTGGATCTT length:  15
# loop:  4 sup:  TGCCTATTGATCTTGG length:  16
# loop:  4 sup:  TGCCTATTGATGGCTT length:  16
# loop:  4 sup:  TGCTTCCTGGATT length:  13
# loop:  4 sup:  TGCTTCCTGGATTGAT length:  16
# loop:  4 sup:  TGCTTCCTGATGGATT length:  16
# loop:  4 sup:  TGCTTCCTGATTGG length:  14
# loop:  4 sup:  TGCTTCCTATTGGAT length:  15
# loop:  4 sup:  TGCTTCCTATTGATGG length:  16
# loop:  4 sup:  TGCTTGGCCTGATT length:  14
# loop:  4 sup:  TGCTTGGCCTATTGAT length:  16
# loop:  4 sup:  TGCTTGGATCCTATT length:  15
# loop:  4 sup:  TGCTTGGATTCCT length:  13
# loop:  4 sup:  TGCTTGGATTCCTGAT length:  16
# loop:  4 sup:  TGCTTGGATTGATCCT length:  16
# loop:  4 sup:  TGCTTGATCCTGGATT length:  16
# loop:  4 sup:  TGCTTGATCCTATTGG length:  16
# loop:  4 sup:  TGCTTGATGGCCTATT length:  16
# loop:  4 sup:  TGCTTGATGGATTCCT length:  16
# loop:  4 sup:  TGCTTGATTCCTGG length:  14
# loop:  4 sup:  TGCTTGATTGGCCT length:  14
# loop:  4 sup:  TGCTTATTCCTGGAT length:  15
# loop:  4 sup:  TGCTTATTCCTGATGG length:  16
# loop:  4 sup:  TGCTTATTGGCCTGAT length:  16
# loop:  4 sup:  TGCTTATTGGATCCT length:  15
# loop:  4 sup:  TGCTTATTGATCCTGG length:  16
# loop:  4 sup:  TGCTTATTGATGGCCT length:  16
# loop:  4 sup:  TGCTGGCCTTGATT length:  14
# loop:  4 sup:  TGCTGGCCTTATTGAT length:  16
# loop:  4 sup:  TGCTGGCCTGATCTTATT length:  18
# loop:  4 sup:  TGCTGGCCTGATTCTT length:  16
# loop:  4 sup:  TGCTGGCCTATTCTTGAT length:  18
# loop:  4 sup:  TGCTGGCCTATTGATCTT length:  18
# loop:  4 sup:  TGCTGGCTTCCTGATT length:  16
# loop:  4 sup:  TGCTGGCTTCCTATTGAT length:  18
# loop:  4 sup:  TGCTGGCTTGATCCTATT length:  18
# loop:  4 sup:  TGCTGGCTTGATTCCT length:  16
# loop:  4 sup:  TGCTGGCTTATTCCTGAT length:  18
# loop:  4 sup:  TGCTGGCTTATTGATCCT length:  18
# loop:  4 sup:  TGCTGGATCCTTATT length:  15
# loop:  4 sup:  TGCTGGATCCTATTCTT length:  17
# loop:  4 sup:  TGCTGGATCTTCCTATT length:  17
# loop:  4 sup:  TGCTGGATCTTATTCCT length:  17
# loop:  4 sup:  TGCTGGATTCCTT length:  13
# loop:  4 sup:  TGCTGGATTCTTCCT length:  15
# loop:  4 sup:  TGCTGGATTCCTTGAT length:  16
# loop:  4 sup:  TGCTGGATTCCTGATCTT length:  18
# loop:  4 sup:  TGCTGGATTCTTCCTGAT length:  18
# loop:  4 sup:  TGCTGGATTCTTGATCCT length:  18
# loop:  4 sup:  TGCTGGATTGATCCTT length:  16
# loop:  4 sup:  TGCTGGATTGATCTTCCT length:  18
# loop:  4 sup:  TGCGATCCTTGGATT length:  15
# loop:  4 sup:  TGCGATCCTTATTGG length:  15
# loop:  4 sup:  TGCGATCCTGGCTTATT length:  17
# loop:  4 sup:  TGCGATCCTGGATTCTT length:  17
# loop:  4 sup:  TGCGATCCTATTCTTGG length:  17
# loop:  4 sup:  TGCGATCCTATTGGCTT length:  17
# loop:  4 sup:  TGCGATCTTCCTGGATT length:  17
# loop:  4 sup:  TGCGATCTTCCTATTGG length:  17
# loop:  4 sup:  TGCGATCTTGGCCTATT length:  17
# loop:  4 sup:  TGCGATCTTGGATTCCT length:  17
# loop:  4 sup:  TGCGATCTTATTCCTGG length:  17
# loop:  4 sup:  TGCGATCTTATTGGCCT length:  17
# loop:  4 sup:  TGCGATGGCCTTATT length:  15
# loop:  4 sup:  TGCGATGGCCTATTCTT length:  17
# loop:  4 sup:  TGCGATGGCTTCCTATT length:  17
# loop:  4 sup:  TGCGATGGCTTATTCCT length:  17
# loop:  4 sup:  TGCGATGGATTCCTT length:  15
# loop:  4 sup:  TGCGATGGATTCTTCCT length:  17
# loop:  4 sup:  TGCGATTCCTTGG length:  13
# loop:  4 sup:  TGCGATTCCTGGCTT length:  15
# loop:  4 sup:  TGCGATTCTTCCTGG length:  15
# loop:  4 sup:  TGCGATTCTTGGCCT length:  15
# loop:  4 sup:  TGCGATTGGCCTT length:  13
# loop:  4 sup:  TGCGATTGGCTTCCT length:  15
# loop:  4 sup:  TGCATTCCTTGGAT length:  14
# loop:  4 sup:  TGCATTCCTTGATGG length:  15
# loop:  4 sup:  TGCATTCCTGGCTTGAT length:  17
# loop:  4 sup:  TGCATTCCTGGATCTT length:  16
# loop:  4 sup:  TGCATTCCTGATCTTGG length:  17
# loop:  4 sup:  TGCATTCCTGATGGCTT length:  17
# loop:  4 sup:  TGCATTCTTCCTGGAT length:  16
# loop:  4 sup:  TGCATTCTTCCTGATGG length:  17
# loop:  4 sup:  TGCATTCTTGGCCTGAT length:  17
# loop:  4 sup:  TGCATTCTTGGATCCT length:  16
# loop:  4 sup:  TGCATTCTTGATCCTGG length:  17
# loop:  4 sup:  TGCATTCTTGATGGCCT length:  17
# loop:  4 sup:  TGCATTGGCCTTGAT length:  15
# loop:  4 sup:  TGCATTGGCCTGATCTT length:  17
# loop:  4 sup:  TGCATTGGCTTCCTGAT length:  17
# loop:  4 sup:  TGCATTGGCTTGATCCT length:  17
# loop:  4 sup:  TGCATTGGATCCTT length:  14
# loop:  4 sup:  TGCATTGGATCTTCCT length:  16
# loop:  4 sup:  TGCATTGATCCTTGG length:  15
# loop:  4 sup:  TGCATTGATCCTGGCTT length:  17
# loop:  4 sup:  TGCATTGATCTTCCTGG length:  17
# loop:  4 sup:  TGCATTGATCTTGGCCT length:  17
# loop:  4 sup:  TGCATTGATGGCCTT length:  15
# loop:  4 sup:  TGCATTGATGGCTTCCT length:  17
# loop:  4 sup:  TGGCCTTGCGATT length:  13
# loop:  4 sup:  TGGCCTTGCATTGAT length:  15
# loop:  4 sup:  TGGCCTTGATGCATT length:  15
# loop:  4 sup:  TGGCCTTGATTGC length:  13
# loop:  4 sup:  TGGCCTTATTGCGAT length:  15
# loop:  4 sup:  TGGCCTTATTGATGC length:  15
# loop:  4 sup:  TGGCCTGCTTGATT length:  14
# loop:  4 sup:  TGGCCTGCTTATTGAT length:  16
# loop:  4 sup:  TGGCCTGCGATCTTATT length:  17
# loop:  4 sup:  TGGCCTGCGATTCTT length:  15
# loop:  4 sup:  TGGCCTGCATTCTTGAT length:  17
# loop:  4 sup:  TGGCCTGCATTGATCTT length:  17
# loop:  4 sup:  TGGCCTGATCTTGCATT length:  17
# loop:  4 sup:  TGGCCTGATCTTATTGC length:  17
# loop:  4 sup:  TGGCCTGATGCTTATT length:  16
# loop:  4 sup:  TGGCCTGATGCATTCTT length:  17
# loop:  4 sup:  TGGCCTGATTCTTGC length:  15
# loop:  4 sup:  TGGCCTGATTGCTT length:  14
# loop:  4 sup:  TGGCCTATTCTTGCGAT length:  17
# loop:  4 sup:  TGGCCTATTCTTGATGC length:  17
# loop:  4 sup:  TGGCCTATTGCTTGAT length:  16
# loop:  4 sup:  TGGCCTATTGCGATCTT length:  17
# loop:  4 sup:  TGGCCTATTGATCTTGC length:  17
# loop:  4 sup:  TGGCCTATTGATGCTT length:  16
# loop:  4 sup:  TGGCTTCCTGCGATT length:  15
# loop:  4 sup:  TGGCTTCCTGCATTGAT length:  17
# loop:  4 sup:  TGGCTTCCTGATGCATT length:  17
# loop:  4 sup:  TGGCTTCCTGATTGC length:  15
# loop:  4 sup:  TGGCTTCCTATTGCGAT length:  17
# loop:  4 sup:  TGGCTTCCTATTGATGC length:  17
# loop:  4 sup:  TGGCTTGCCTGATT length:  14
# loop:  4 sup:  TGGCTTGCCTATTGAT length:  16
# loop:  4 sup:  TGGCTTGCGATCCTATT length:  17
# loop:  4 sup:  TGGCTTGCGATTCCT length:  15
# loop:  4 sup:  TGGCTTGCATTCCTGAT length:  17
# loop:  4 sup:  TGGCTTGCATTGATCCT length:  17
# loop:  4 sup:  TGGCTTGATCCTGCATT length:  17
# loop:  4 sup:  TGGCTTGATCCTATTGC length:  17
# loop:  4 sup:  TGGCTTGATGCCTATT length:  16
# loop:  4 sup:  TGGCTTGATGCATTCCT length:  17
# loop:  4 sup:  TGGCTTGATTCCTGC length:  15
# loop:  4 sup:  TGGCTTGATTGCCT length:  14
# loop:  4 sup:  TGGCTTATTCCTGCGAT length:  17
# loop:  4 sup:  TGGCTTATTCCTGATGC length:  17
# loop:  4 sup:  TGGCTTATTGCCTGAT length:  16
# loop:  4 sup:  TGGCTTATTGCGATCCT length:  17
# loop:  4 sup:  TGGCTTATTGATCCTGC length:  17
# loop:  4 sup:  TGGCTTATTGATGCCT length:  16
# loop:  4 sup:  TGGTGCCTTGATT length:  13
# loop:  4 sup:  TGGTGCCTTATTGAT length:  15
# loop:  4 sup:  TGGTGCCTGATCTTATT length:  17
# loop:  4 sup:  TGGTGCCTGATTCTT length:  15
# loop:  4 sup:  TGGTGCCTATTCTTGAT length:  17
# loop:  4 sup:  TGGTGCCTATTGATCTT length:  17
# loop:  4 sup:  TGGTGCTTCCTGATT length:  15
# loop:  4 sup:  TGGTGCTTCCTATTGAT length:  17
# loop:  4 sup:  TGGTGCTTGATCCTATT length:  17
# loop:  4 sup:  TGGTGCTTGATTCCT length:  15
# loop:  4 sup:  TGGTGCTTATTCCTGAT length:  17
# loop:  4 sup:  TGGTGCTTATTGATCCT length:  17
# loop:  4 sup:  TGGTGCGATCCTTATT length:  16
# loop:  4 sup:  TGGTGCGATCCTATTCTT length:  18
# loop:  4 sup:  TGGTGCGATCTTCCTATT length:  18
# loop:  4 sup:  TGGTGCGATCTTATTCCT length:  18
# loop:  4 sup:  TGGTGCGATTCCTT length:  14
# loop:  4 sup:  TGGTGCGATTCTTCCT length:  16
# loop:  4 sup:  TGGTGCATTCCTTGAT length:  16
# loop:  4 sup:  TGGTGCATTCCTGATCTT length:  18
# loop:  4 sup:  TGGTGCATTCTTCCTGAT length:  18
# loop:  4 sup:  TGGTGCATTCTTGATCCT length:  18
# loop:  4 sup:  TGGTGCATTGATCCTT length:  16
# loop:  4 sup:  TGGTGCATTGATCTTCCT length:  18
# loop:  4 sup:  TGGATCCTTGCATT length:  14
# loop:  4 sup:  TGGATCCTTATTGC length:  14
# loop:  4 sup:  TGGATCCTGCTTATT length:  15
# loop:  4 sup:  TGGATCCTGCATTCTT length:  16
# loop:  4 sup:  TGGATCCTATTCTTGC length:  16
# loop:  4 sup:  TGGATCCTATTGCTT length:  15
# loop:  4 sup:  TGGATCTTCCTGCATT length:  16
# loop:  4 sup:  TGGATCTTCCTATTGC length:  16
# loop:  4 sup:  TGGATCTTGCCTATT length:  15
# loop:  4 sup:  TGGATCTTGCATTCCT length:  16
# loop:  4 sup:  TGGATCTTATTCCTGC length:  16
# loop:  4 sup:  TGGATCTTATTGCCT length:  15
# loop:  4 sup:  TGGATGCCTTATT length:  13
# loop:  4 sup:  TGGATGCCTATTCTT length:  15
# loop:  4 sup:  TGGATGCTTCCTATT length:  15
# loop:  4 sup:  TGGATGCTTATTCCT length:  15
# loop:  4 sup:  TGGATGCATTCCTT length:  14
# loop:  4 sup:  TGGATGCATTCTTCCT length:  16
# loop:  4 sup:  TGGATTCCTTGC length:  12
# loop:  4 sup:  TGGATTCCTGCTT length:  13
# loop:  4 sup:  TGGATTCTTCCTGC length:  14
# loop:  4 sup:  TGGATTCTTGCCT length:  13
# loop:  4 sup:  TGGATTGCCTT length:  11
# count:  3
# loop:  4 sup:  TGGATTGCTTCCT length:  13
# loop:  4 sup:  TGGATTCCTTGCGAT length:  15
# loop:  4 sup:  TGGATTCCTTGATGC length:  15
# loop:  4 sup:  TGGATTCCTGCTTGAT length:  16
# loop:  4 sup:  TGGATTCCTGCGATCTT length:  17
# loop:  4 sup:  TGGATTCCTGATCTTGC length:  17
# loop:  4 sup:  TGGATTCCTGATGCTT length:  16
# loop:  4 sup:  TGGATTCTTCCTGCGAT length:  17
# loop:  4 sup:  TGGATTCTTCCTGATGC length:  17
# loop:  4 sup:  TGGATTCTTGCCTGAT length:  16
# loop:  4 sup:  TGGATTCTTGCGATCCT length:  17
# loop:  4 sup:  TGGATTCTTGATCCTGC length:  17
# loop:  4 sup:  TGGATTCTTGATGCCT length:  16
# loop:  4 sup:  TGGATTGCCTTGAT length:  14
# loop:  4 sup:  TGGATTGCCTGATCTT length:  16
# loop:  4 sup:  TGGATTGCTTCCTGAT length:  16
# loop:  4 sup:  TGGATTGCTTGATCCT length:  16
# loop:  4 sup:  TGGATTGCGATCCTT length:  15
# loop:  4 sup:  TGGATTGCGATCTTCCT length:  17
# loop:  4 sup:  TGGATTGATCCTTGC length:  15
# loop:  4 sup:  TGGATTGATCCTGCTT length:  16
# loop:  4 sup:  TGGATTGATCTTCCTGC length:  17
# loop:  4 sup:  TGGATTGATCTTGCCT length:  16
# loop:  4 sup:  TGGATTGATGCCTT length:  14
# loop:  4 sup:  TGGATTGATGCTTCCT length:  16
# loop:  4 sup:  GATCCTTGCTGGATT length:  15
# loop:  4 sup:  GATCCTTGCATTGG length:  14
# loop:  4 sup:  GATCCTTGGTGCATT length:  15
# loop:  4 sup:  GATCCTTGGATTGC length:  14
# loop:  4 sup:  GATCCTTATTGCTGG length:  15
# loop:  4 sup:  GATCCTTATTGGTGC length:  15
# loop:  4 sup:  GATCCTGCTTGGATT length:  15
# loop:  4 sup:  GATCCTGCTTATTGG length:  15
# loop:  4 sup:  GATCCTGCTGGCTTATT length:  17
# loop:  4 sup:  GATCCTGCTGGATTCTT length:  17
# loop:  4 sup:  GATCCTGCATTCTTGG length:  16
# loop:  4 sup:  GATCCTGCATTGGCTT length:  16
# loop:  4 sup:  GATCCTGGCTTGCATT length:  16
# loop:  4 sup:  GATCCTGGCTTATTGC length:  16
# loop:  4 sup:  GATCCTGGTGCTTATT length:  16
# loop:  4 sup:  GATCCTGGTGCATTCTT length:  17
# loop:  4 sup:  GATCCTGGATTCTTGC length:  16
# loop:  4 sup:  GATCCTGGATTGCTT length:  15
# loop:  4 sup:  GATCCTATTCTTGCTGG length:  17
# loop:  4 sup:  GATCCTATTCTTGGTGC length:  17
# loop:  4 sup:  GATCCTATTGCTTGG length:  15
# loop:  4 sup:  GATCCTATTGCTGGCTT length:  17
# loop:  4 sup:  GATCCTATTGGCTTGC length:  16
# loop:  4 sup:  GATCCTATTGGTGCTT length:  16
# loop:  4 sup:  GATCTTCCTGCTGGATT length:  17
# loop:  4 sup:  GATCTTCCTGCATTGG length:  16
# loop:  4 sup:  GATCTTCCTGGTGCATT length:  17
# loop:  4 sup:  GATCTTCCTGGATTGC length:  16
# loop:  4 sup:  GATCTTCCTATTGCTGG length:  17
# loop:  4 sup:  GATCTTCCTATTGGTGC length:  17
# loop:  4 sup:  GATCTTGCCTGGATT length:  15
# loop:  4 sup:  GATCTTGCCTATTGG length:  15
# loop:  4 sup:  GATCTTGCTGGCCTATT length:  17
# loop:  4 sup:  GATCTTGCTGGATTCCT length:  17
# loop:  4 sup:  GATCTTGCATTCCTGG length:  16
# loop:  4 sup:  GATCTTGCATTGGCCT length:  16
# loop:  4 sup:  GATCTTGGCCTGCATT length:  16
# loop:  4 sup:  GATCTTGGCCTATTGC length:  16
# loop:  4 sup:  GATCTTGGTGCCTATT length:  16
# loop:  4 sup:  GATCTTGGTGCATTCCT length:  17
# loop:  4 sup:  GATCTTGGATTCCTGC length:  16
# loop:  4 sup:  GATCTTGGATTGCCT length:  15
# loop:  4 sup:  GATCTTATTCCTGCTGG length:  17
# loop:  4 sup:  GATCTTATTCCTGGTGC length:  17
# loop:  4 sup:  GATCTTATTGCCTGG length:  15
# loop:  4 sup:  GATCTTATTGCTGGCCT length:  17
# loop:  4 sup:  GATCTTATTGGCCTGC length:  16
# loop:  4 sup:  GATCTTATTGGTGCCT length:  16
# loop:  4 sup:  GATGCCTTGGATT length:  13
# loop:  4 sup:  GATGCCTTATTGG length:  13
# loop:  4 sup:  GATGCCTGGCTTATT length:  15
# loop:  4 sup:  GATGCCTGGATTCTT length:  15
# loop:  4 sup:  GATGCCTATTCTTGG length:  15
# loop:  4 sup:  GATGCCTATTGGCTT length:  15
# loop:  4 sup:  GATGCTTCCTGGATT length:  15
# loop:  4 sup:  GATGCTTCCTATTGG length:  15
# loop:  4 sup:  GATGCTTGGCCTATT length:  15
# loop:  4 sup:  GATGCTTGGATTCCT length:  15
# loop:  4 sup:  GATGCTTATTCCTGG length:  15
# loop:  4 sup:  GATGCTTATTGGCCT length:  15
# loop:  4 sup:  GATGCTGGCCTTATT length:  15
# loop:  4 sup:  GATGCTGGCCTATTCTT length:  17
# loop:  4 sup:  GATGCTGGCTTCCTATT length:  17
# loop:  4 sup:  GATGCTGGCTTATTCCT length:  17
# loop:  4 sup:  GATGCTGGATTCCTT length:  15
# loop:  4 sup:  GATGCTGGATTCTTCCT length:  17
# loop:  4 sup:  GATGCATTCCTTGG length:  14
# loop:  4 sup:  GATGCATTCCTGGCTT length:  16
# loop:  4 sup:  GATGCATTCTTCCTGG length:  16
# loop:  4 sup:  GATGCATTCTTGGCCT length:  16
# loop:  4 sup:  GATGCATTGGCCTT length:  14
# loop:  4 sup:  GATGCATTGGCTTCCT length:  16
# loop:  4 sup:  GATGGCCTTGCATT length:  14
# loop:  4 sup:  GATGGCCTTATTGC length:  14
# loop:  4 sup:  GATGGCCTGCTTATT length:  15
# loop:  4 sup:  GATGGCCTGCATTCTT length:  16
# loop:  4 sup:  GATGGCCTATTCTTGC length:  16
# loop:  4 sup:  GATGGCCTATTGCTT length:  15
# loop:  4 sup:  GATGGCTTCCTGCATT length:  16
# loop:  4 sup:  GATGGCTTCCTATTGC length:  16
# loop:  4 sup:  GATGGCTTGCCTATT length:  15
# loop:  4 sup:  GATGGCTTGCATTCCT length:  16
# loop:  4 sup:  GATGGCTTATTCCTGC length:  16
# loop:  4 sup:  GATGGCTTATTGCCT length:  15
# loop:  4 sup:  GATGGTGCCTTATT length:  14
# loop:  4 sup:  GATGGTGCCTATTCTT length:  16
# loop:  4 sup:  GATGGTGCTTCCTATT length:  16
# loop:  4 sup:  GATGGTGCTTATTCCT length:  16
# loop:  4 sup:  GATGGTGCATTCCTT length:  15
# loop:  4 sup:  GATGGTGCATTCTTCCT length:  17
# loop:  4 sup:  GATGGATTCCTTGC length:  14
# loop:  4 sup:  GATGGATTCCTGCTT length:  15
# loop:  4 sup:  GATGGATTCTTCCTGC length:  16
# loop:  4 sup:  GATGGATTCTTGCCT length:  15
# loop:  4 sup:  GATGGATTGCCTT length:  13
# loop:  4 sup:  GATGGATTGCTTCCT length:  15
# loop:  4 sup:  GATTCCTTGCTGG length:  13
# loop:  4 sup:  GATTCCTTGGTGC length:  13
# loop:  4 sup:  GATTCCTGCTTGG length:  13
# loop:  4 sup:  GATTCCTGCTGGCTT length:  15
# loop:  4 sup:  GATTCCTGGCTTGC length:  14
# loop:  4 sup:  GATTCCTGGTGCTT length:  14
# loop:  4 sup:  GATTCTTCCTGCTGG length:  15
# loop:  4 sup:  GATTCTTCCTGGTGC length:  15
# loop:  4 sup:  GATTCTTGCCTGG length:  13
# loop:  4 sup:  GATTCTTGCTGGCCT length:  15
# loop:  4 sup:  GATTCTTGGCCTGC length:  14
# loop:  4 sup:  GATTCTTGGTGCCT length:  14
# loop:  4 sup:  GATTGCCTTGG length:  11
# count:  4
# loop:  4 sup:  GATTGCCTGGCTT length:  13
# loop:  4 sup:  GATTGCTTCCTGG length:  13
# loop:  4 sup:  GATTGCTTGGCCT length:  13
# loop:  4 sup:  GATTGCTGGCCTT length:  13
# loop:  4 sup:  GATTGCTGGCTTCCT length:  15
# loop:  4 sup:  GATTGGCCTTGC length:  12
# loop:  4 sup:  GATTGGCCTGCTT length:  13
# loop:  4 sup:  GATTGGCTTCCTGC length:  14
# loop:  4 sup:  GATTGGCTTGCCT length:  13
# loop:  4 sup:  GATTGGTGCCTT length:  12
# loop:  4 sup:  GATTGGTGCTTCCT length:  14
# loop:  4 sup:  ATTCCTTGCTGGAT length:  14
# loop:  4 sup:  ATTCCTTGCGATGG length:  14
# loop:  4 sup:  ATTCCTTGGTGCGAT length:  15
# loop:  4 sup:  ATTCCTTGGATGC length:  13
# loop:  4 sup:  ATTCCTTGATGCTGG length:  15
# loop:  4 sup:  ATTCCTTGATGGTGC length:  15
# loop:  4 sup:  ATTCCTGCTTGGAT length:  14
# loop:  4 sup:  ATTCCTGCTTGATGG length:  15
# loop:  4 sup:  ATTCCTGCTGGCTTGAT length:  17
# loop:  4 sup:  ATTCCTGCTGGATCTT length:  16
# loop:  4 sup:  ATTCCTGCGATCTTGG length:  16
# loop:  4 sup:  ATTCCTGCGATGGCTT length:  16
# loop:  4 sup:  ATTCCTGGCTTGCGAT length:  16
# loop:  4 sup:  ATTCCTGGCTTGATGC length:  16
# loop:  4 sup:  ATTCCTGGTGCTTGAT length:  16
# loop:  4 sup:  ATTCCTGGTGCGATCTT length:  17
# loop:  4 sup:  ATTCCTGGATCTTGC length:  15
# loop:  4 sup:  ATTCCTGGATGCTT length:  14
# loop:  4 sup:  ATTCCTGATCTTGCTGG length:  17
# loop:  4 sup:  ATTCCTGATCTTGGTGC length:  17
# loop:  4 sup:  ATTCCTGATGCTTGG length:  15
# loop:  4 sup:  ATTCCTGATGCTGGCTT length:  17
# loop:  4 sup:  ATTCCTGATGGCTTGC length:  16
# loop:  4 sup:  ATTCCTGATGGTGCTT length:  16
# loop:  4 sup:  ATTCTTCCTGCTGGAT length:  16
# loop:  4 sup:  ATTCTTCCTGCGATGG length:  16
# loop:  4 sup:  ATTCTTCCTGGTGCGAT length:  17
# loop:  4 sup:  ATTCTTCCTGGATGC length:  15
# loop:  4 sup:  ATTCTTCCTGATGCTGG length:  17
# loop:  4 sup:  ATTCTTCCTGATGGTGC length:  17
# loop:  4 sup:  ATTCTTGCCTGGAT length:  14
# loop:  4 sup:  ATTCTTGCCTGATGG length:  15
# loop:  4 sup:  ATTCTTGCTGGCCTGAT length:  17
# loop:  4 sup:  ATTCTTGCTGGATCCT length:  16
# loop:  4 sup:  ATTCTTGCGATCCTGG length:  16
# loop:  4 sup:  ATTCTTGCGATGGCCT length:  16
# loop:  4 sup:  ATTCTTGGCCTGCGAT length:  16
# loop:  4 sup:  ATTCTTGGCCTGATGC length:  16
# loop:  4 sup:  ATTCTTGGTGCCTGAT length:  16
# loop:  4 sup:  ATTCTTGGTGCGATCCT length:  17
# loop:  4 sup:  ATTCTTGGATCCTGC length:  15
# loop:  4 sup:  ATTCTTGGATGCCT length:  14
# loop:  4 sup:  ATTCTTGATCCTGCTGG length:  17
# loop:  4 sup:  ATTCTTGATCCTGGTGC length:  17
# loop:  4 sup:  ATTCTTGATGCCTGG length:  15
# loop:  4 sup:  ATTCTTGATGCTGGCCT length:  17
# loop:  4 sup:  ATTCTTGATGGCCTGC length:  16
# loop:  4 sup:  ATTCTTGATGGTGCCT length:  16
# loop:  4 sup:  ATTGCCTTGGAT length:  12
# loop:  4 sup:  ATTGCCTTGATGG length:  13
# loop:  4 sup:  ATTGCCTGGCTTGAT length:  15
# loop:  4 sup:  ATTGCCTGGATCTT length:  14
# loop:  4 sup:  ATTGCCTGATCTTGG length:  15
# loop:  4 sup:  ATTGCCTGATGGCTT length:  15
# loop:  4 sup:  ATTGCTTCCTGGAT length:  14
# loop:  4 sup:  ATTGCTTCCTGATGG length:  15
# loop:  4 sup:  ATTGCTTGGCCTGAT length:  15
# loop:  4 sup:  ATTGCTTGGATCCT length:  14
# loop:  4 sup:  ATTGCTTGATCCTGG length:  15
# loop:  4 sup:  ATTGCTTGATGGCCT length:  15
# loop:  4 sup:  ATTGCTGGCCTTGAT length:  15
# loop:  4 sup:  ATTGCTGGCCTGATCTT length:  17
# loop:  4 sup:  ATTGCTGGCTTCCTGAT length:  17
# loop:  4 sup:  ATTGCTGGCTTGATCCT length:  17
# loop:  4 sup:  ATTGCTGGATCCTT length:  14
# loop:  4 sup:  ATTGCTGGATCTTCCT length:  16
# loop:  4 sup:  ATTGCGATCCTTGG length:  14
# loop:  4 sup:  ATTGCGATCCTGGCTT length:  16
# loop:  4 sup:  ATTGCGATCTTCCTGG length:  16
# loop:  4 sup:  ATTGCGATCTTGGCCT length:  16
# loop:  4 sup:  ATTGCGATGGCCTT length:  14
# loop:  4 sup:  ATTGCGATGGCTTCCT length:  16
# loop:  4 sup:  ATTGGCCTTGCGAT length:  14
# loop:  4 sup:  ATTGGCCTTGATGC length:  14
# loop:  4 sup:  ATTGGCCTGCTTGAT length:  15
# loop:  4 sup:  ATTGGCCTGCGATCTT length:  16
# loop:  4 sup:  ATTGGCCTGATCTTGC length:  16
# loop:  4 sup:  ATTGGCCTGATGCTT length:  15
# loop:  4 sup:  ATTGGCTTCCTGCGAT length:  16
# loop:  4 sup:  ATTGGCTTCCTGATGC length:  16
# loop:  4 sup:  ATTGGCTTGCCTGAT length:  15
# loop:  4 sup:  ATTGGCTTGCGATCCT length:  16
# loop:  4 sup:  ATTGGCTTGATCCTGC length:  16
# loop:  4 sup:  ATTGGCTTGATGCCT length:  15
# loop:  4 sup:  ATTGGTGCCTTGAT length:  14
# loop:  4 sup:  ATTGGTGCCTGATCTT length:  16
# loop:  4 sup:  ATTGGTGCTTCCTGAT length:  16
# loop:  4 sup:  ATTGGTGCTTGATCCT length:  16
# loop:  4 sup:  ATTGGTGCGATCCTT length:  15
# loop:  4 sup:  ATTGGTGCGATCTTCCT length:  17
# loop:  4 sup:  ATTGGATCCTTGC length:  13
# loop:  4 sup:  ATTGGATCCTGCTT length:  14
# loop:  4 sup:  ATTGGATCTTCCTGC length:  15
# loop:  4 sup:  ATTGGATCTTGCCT length:  14
# loop:  4 sup:  ATTGGATGCCTT length:  12
# loop:  4 sup:  ATTGGATGCTTCCT length:  14
# loop:  4 sup:  ATTGATCCTTGCTGG length:  15
# loop:  4 sup:  ATTGATCCTTGGTGC length:  15
# loop:  4 sup:  ATTGATCCTGCTTGG length:  15
# loop:  4 sup:  ATTGATCCTGCTGGCTT length:  17
# loop:  4 sup:  ATTGATCCTGGCTTGC length:  16
# loop:  4 sup:  ATTGATCCTGGTGCTT length:  16
# loop:  4 sup:  ATTGATCTTCCTGCTGG length:  17
# loop:  4 sup:  ATTGATCTTCCTGGTGC length:  17
# loop:  4 sup:  ATTGATCTTGCCTGG length:  15
# loop:  4 sup:  ATTGATCTTGCTGGCCT length:  17
# loop:  4 sup:  ATTGATCTTGGCCTGC length:  16
# loop:  4 sup:  ATTGATCTTGGTGCCT length:  16
# loop:  4 sup:  ATTGATGCCTTGG length:  13
# loop:  4 sup:  ATTGATGCCTGGCTT length:  15
# loop:  4 sup:  ATTGATGCTTCCTGG length:  15
# loop:  4 sup:  ATTGATGCTTGGCCT length:  15
# loop:  4 sup:  ATTGATGCTGGCCTT length:  15
# loop:  4 sup:  ATTGATGCTGGCTTCCT length:  17
# loop:  4 sup:  ATTGATGGCCTTGC length:  14
# loop:  4 sup:  ATTGATGGCCTGCTT length:  15
# loop:  4 sup:  ATTGATGGCTTCCTGC length:  16
# loop:  4 sup:  ATTGATGGCTTGCCT length:  15
# loop:  4 sup:  ATTGATGGTGCCTT length:  14
# loop:  4 sup:  ATTGATGGTGCTTCCT length:  16
# 'CCTTGGATTGC'

# %%
len('CCTTGGATTGC')
# Out:
# 11

# %%
def overlap(a, b, min_length):
    """ Return length of longest suffix of 'a' matching
        a prefix of 'b' that is at least 'min_length'
        characters long.  If no such overlap exists,
        return 0. """
    start = 0  # start all the way at the left
    while True:
        start = a.find(b[:min_length], start)  # look for b's suffx in a
        if start == -1:  # no more occurrences to right
            return 0
        # found occurrence; check for full suffix/prefix match
        if b.startswith(a[start:]):
            return len(a)-start
        start += 1  # move just past previous match

# %%
#Because the reads are quite large. len(seqs) = 1340. 
#Our greedy algorithm code is quite slow as it has to do overlap comparsions a total of :
#n! + n-1! + n-2! ... 1 times, which will be very very large
#So lets accelerate the algorithm.

def pick_maximal_overlap(reads, k):
    reada, readb = None, None
    best_olen = 0
    greedy = {}
    for a,b in itertools.permutations(reads, 2):
        if not greedy.get((a,b),None) == None: 
    #searches the keys in the greedy dictionary and returns value, else returns None
            continue
        olen = overlap(a, b, min_length=k)
        greedy[(a,b)] = olen
        if olen > best_olen:
            reada, readb = a, b
            best_olen = olen
    return reada, readb, best_olen

def greedy_scs(reads, k):
    read_a, read_b, olen = pick_maximal_overlap(reads, k)
    while olen > 0:
        reads.remove(read_a)
        reads.remove(read_b)
        reads.append(read_a + read_b[olen:])
        read_a, read_b, olen = pick_maximal_overlap(reads, k)
    return ''.join(reads) #even though there are no more overlaps/edges in the overlap graph but there still are reads/nodes left we would concatinate them as well.

# %%
def readFastq(filename):
    sequences = []
    qualities = []
    n = 0
    l = []
    with open(filename, 'r') as fh:
        while True:
            fh.readline() #skip name line
            seq = fh.readline().rstrip() #read base sequences
            fh.readline() #skip placeholder line
            qual = fh.readline().rstrip() # read base quality line
            if len(seq) == 0:
                break #end of the file
            sequences.append(seq)
            qualities.append(qual)
    return sequences, qualities
seqs, _ = readFastq("ads1_week4_reads.fastq")

# %%
len(seqs)
# Out:
# 1881

# %%
genome = greedy_scs(seqs, 10)
#This is still very slow.

# %%
# The virus genome should be 15,894 bases long.
len(genome)
# Out:
# 188100

# %%
#Because the reads are quite large. len(seqs) = 1340. 
#Our greedy algorithm code is quite slow as it has to do overlap comparsions a total of :
#n! + n-1! + n-2! ... 1 times, which will be very very large
#So lets accelerate the algorithm.

#This could be done by making a index of all the text/reads where we store the prefix of k length and 
#associate the prefix with a set of reads that contain it. 
#'ACCATT': set(ACCATTGGGGGG, ACCATTAAAAA)
#Then querry the suffix of each pattern/reads in the index, find the associated read in the set
#If the read does not match the read that suffix belongs to, then do overlap comparsions
#This ensures only performing overlap comparisions between reads that actually has suffix=prefix.

#reads are the reads in fastq files and k is the minimum overlap required
def pick_maximal_overlap_index(reads, k):
    index = {} #making an index with the help of dictionary 
    for read in reads:
        kmers = [] #to store a list of prefix of length 'k'
        for i in range(len(read) - k + 1): #generating prefixes from text/reads
            kmers.append(read[i:i+k])
        for kmer in kmers: #Then storing the k-mer prefixes in the dictionary
            if kmer not in index:
                index[kmer] = set() #value is stored in set so as to only store unique reads
            index[kmer].add(read) #the reads are stored as the values and their prefixes are the keys
            
    #Now storing the reads with maximum edges/olen for greedy algorithm
    reada, readb = None, None
    best_olen = 0
    #Only finding overlap whoes read1_suffix == read2_prefix
    for a in reads: 
        #Compare the suffix of the pattern/reads in the index 
        for b in index[a[-k:]]: #a[-k:] is the suffix of length 'k' (last k characters of the string 'a')
            if a != b: #b is the read associated with the prefix who matches the suffix
                olen = overlap(a, b, k)
                if olen > best_olen:
                    reada, readb = a, b
                    best_olen = olen
    return reada, readb, best_olen


#This function implements the greedy shortest common superstring algorithm using an accelerated version of pick_maximal_overlap(reads, k).

def greedy_scs_index(reads, k):
    read_a, read_b, olen = pick_maximal_overlap_index(reads, k)
    while olen > 0:
        #print(len(reads))
        reads.remove(read_a)
        reads.remove(read_b)
        reads.append(read_a + read_b[olen:])
        read_a, read_b, olen = pick_maximal_overlap_index(reads, k)
    return ''.join(reads)

# %%
genome = greedy_scs_index(seqs, 10)

# %%
# The virus genome should be 15,894 bases long.
len(genome)
# Out:
# 15894

# %%
genome.count('A')
# Out:
# 4633

# %%
genome.count('T')
# Out:
# 3723

# %%
#Using algorithm for total number of A's and T's in the assembled genome
def findBases(genome, b):
    a = 0
    for base in genome:
        if base == b:
            a += 1
    return a
# Counting the number of As in the fully assembled genome:
print(findBases(genome, 'A'))

print(findBases(genome, 'T'))
